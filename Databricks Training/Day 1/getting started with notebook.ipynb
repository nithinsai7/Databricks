# %% [markdown]
# ## Databricks Training Day 1

# %%
print("hello")

# %%
# %sql
select "Running SQL"

# %% [markdown]
# Data Objects
# Catalog
# Schema
# Table View Functions Volume

# %% [markdown]
# ![](/Volumes/acc_dev/naval/raw/object-model.png)

# %%
# %sql
use catalog acc_dev;
create schema nithin;

# %%
# %sql
use catalog acc_dev;
use schema nithin;

# %%
# %sql
create table demo (id int primary key);
