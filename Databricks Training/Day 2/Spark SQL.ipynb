# %%
# %sql
create table acc_dev.nithin.house_ctas as 
select * from parquet.`/Volumes/acc_dev/naval/raw/house-price.parquet`

# %%
# %sql
create table acc_dev.nithin.finance_ctas as 
select * from read_files("/Volumes/acc_dev/naval/raw/financial_dataset.csv" , format=>"csv")

# %%
# %sql
create or replace table acc_dev.nithin.orders_ctas as
select * from json.`/Volumes/acc_dev/naval/raw/retail_orders.json`
