# %%
spark

# %% [markdown]
# https://spark.apache.org/docs/latest/api/python/getting_started/quickstart_df.html

# %%
data = (['1','a'],['2','b'])
schema = ['id','name']
df = spark.createDataFrame(data, ['id','name'])
df.show()

# %%
df.display()

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df.show()

# %%
df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')
df.display()

# %%
pandas_df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [2., 3., 4.],
    'c': ['string1', 'string2', 'string3'],
    'd': [date(2000, 1, 1), date(2000, 2, 1), date(2000, 3, 1)],
    'e': [datetime(2000, 1, 1, 12, 0), datetime(2000, 1, 2, 12, 0), datetime(2000, 1, 3, 12, 0)]
})
df = spark.createDataFrame(pandas_df)
df.display()

# %% [markdown]
# Reader API

# %%
#df_sales=spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv")
df_sales=spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv",header=True,inferSchema=True)

# %%
df_sales.write.saveAsTable("acc_dev.nithin.sales_py")

# %%
df_sales=spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv",header=True,inferSchema=True)
df_sales.write.mode("overwrite").saveAsTable("acc_dev.nithin.sales_py")

# %%
df_price = spark.read.parquet("/Volumes/acc_dev/naval/raw/house-price.parquet")

# %%
df_price.display()

# %%
df_price.write.mode("append").saveAsTable("acc_dev.nithin.house_price_py")

# %%
# %sql
select * from acc_dev.nithin.house_price_py;

# %%
df_orders = spark.read.json("/Volumes/acc_dev/naval/raw/retail_orders.json")
df_orders.display()

# %%
df_orders.write.mode("overwrite").saveAsTable("acc_dev.nithin.orders_py")

# %%
# %sql
select * from acc_dev.nithin.orders_py;
