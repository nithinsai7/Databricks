# %%
# %run "/Workspace/Users/nithinsaireddy7@gmail.com/Databricks Training/Day 2/requirements"

# %%
df = spark.read.csv(input_path,header = True,inferSchema = True)

# %%
new_col=['transaction_id',
 'customer_id',
 'account_type',
 'transaction_type',
 'amount_usd',
 'branch',
 'transaction_date']

# %%
df1=df.toDF(*new_col).withColumn("ingestion_date", current_timestamp()).withColumn("path",col("_metadata.file_name"))

# %%
df1.write.mode("overwrite").saveAsTable("acc_dev.nithin.financial_py")
