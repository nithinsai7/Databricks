# %%
df=spark.read.csv("/Volumes/acc_dev/naval/raw/financial_dataset.csv",header=True,inferSchema=True)
display(df)

# %%
df.select("TransactionID","TransactionDate","AmountUSD")

# %%
df.filter("customerid == 'CUST0008'").display()

# %%
df.filter("customerid == 'CUST0008'").explain(True)

# %%
df.select("CustomerID".alias("custid"))

# %%
from pyspark.sql.functions import *

# %%
df.select(col("CustomerID").alias("custid")).display()

# %%
df.withColumnRenamed("CustomerID","Custid").withColumnRenamed("AccountType" , "Acct_type").display()

# %%
df.withColumnsRenamed({"CustomerID":"custid","AccountType":"acct_type"}).display()

# %%
df.withColumn("Branch" , upper("Branch")).display()

# %%
df.withColumn("Ingestion_time" , current_timestamp()).display()
