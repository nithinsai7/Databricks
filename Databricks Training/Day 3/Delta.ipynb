-- %%
%sql
use catalog acc_dev;
use schema nithin;

-- %%
%sql
CREATE TABLE IF NOT EXISTS emp (id INT, name STRING, dept STRING);

-- %%
%sql
insert into table emp values(3,'sanjana', 'data')

-- %%
%sql
desc detail emp

-- %%
desc history emp

-- %%
select * from emp;

-- %%
delete from emp where id = 2;

-- %%
desc history emp;

-- %%
select * from emp version as of 4;

-- %%
insert into acc_Dev.naval.emp values(0278 , 'nithin' ,'mahabubnagar');

-- %%
select * from emp timestamp as of '2025-11-05T04:55:52.000+00:00';

-- %%
delete from emp;

-- %%
select * from emp

-- %%
restore table emp version as of 4;
select * from emp;
