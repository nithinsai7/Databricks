# %%
# %run "/Workspace/Users/nithinsaireddy7@gmail.com/Databricks Training/Day 3/Meddalion/Bronze"

# %%
df = spark.table(f'{catalog}.{schema}.sales')

df1 = df.dropDuplicates().dropna().drop('ingestion_date', 'path')
df1.write.mode('overwrite').saveAsTable(f'{catalog}.nithin_silver.sales_cleaned')

# %%
# %sql
# select * from acc_dev.nithin_silver.sales_cleaned;
