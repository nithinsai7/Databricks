# %%
# %run "/Workspace/Users/nithinsaireddy7@gmail.com/Databricks Training/Day 3/Meddalion/Silver"

# %%
# %sql
create or replace view acc_dev.nithin_gold.top_products as (
  select product_id, sum(quantity) as total_quantity from acc_dev.nithin_silver.sales_cleaned group by product_id order by total_quantity desc
)

# %%
# %sql
select * from acc_dev.nithin_gold.top_products;
