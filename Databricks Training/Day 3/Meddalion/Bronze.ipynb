# %%
# %run "/Workspace/Users/nithinsaireddy7@gmail.com/Databricks Training/Day 3/Meddalion/Requirements"

# %%
df=spark.read.csv(f"{input_path}{file_name}.csv",header=True,inferSchema=True)

# %%
df1=new_col(df)

# %%
df1.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.{file_name}")

# %%
# %sql
grant use schema on schema acc_dev.nithin_bronze to `ritheshadep@gmail.com`;
grant select on schema acc_dev.nithin_bronze to `ritheshadep@gmail.com`

# %%
# %sql
select * from acc_dev.naval_gold.agg_heartrate;
